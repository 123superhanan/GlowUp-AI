# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/623.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/138 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/537.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/56.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/654.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/89.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/20.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/58.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/14 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/134 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/149.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/521.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/539.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/516.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/708.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/97 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/646.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/160 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/682.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/576.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/159 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/613.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/703.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/162 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/136 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/626.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/20 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/141 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/641.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/622.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/534.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/84.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/57 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/577.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/513.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/85.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/564.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/67.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/60 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/118.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/591.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/137 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/30.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/97.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/106.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/163.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/88 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/160.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/518.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/4 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/704.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/630.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/33.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/54.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/672.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/83 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/683.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/0.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/62.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/589.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/558.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/120.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/629.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/61.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/124.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/121 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/59.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/604.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/680.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/595.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/85 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/73.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/601.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/98.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/527.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/620.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/123.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/710.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/580.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/685.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/559.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/94.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/60.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/627.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/538.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/57.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/515.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/690.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/639.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/701.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/91.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/653.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/9.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/705.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/101.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/651.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/147 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/99.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/524.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/529.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/146 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/642.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/69.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/123 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/11 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/684.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/535.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/139 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/15 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/560.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/137.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/716.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/525.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/68 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/574.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/44.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/561.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/563.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/65.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/50.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/530.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/569.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/140.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/531.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/713.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/148 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/590.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/695.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/649.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/634.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/619.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/611.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/658.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/135.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/23.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/541.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/659.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/548.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/699.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/77.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/159.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/87 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/faces.csv
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/121.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/628.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/645.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/573.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/691.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/677.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/671.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/640.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/678.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/603.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/565.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/40.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/543.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/700.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/554.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/633.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/687.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/48.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/631.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/532.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/572.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/555.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/656.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/545.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/24.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/567.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/88.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/64.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/99 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/702.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/636.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/587.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/575.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/148.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/31.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/586.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/114.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/552.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/693.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/43.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/709.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/138.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/650.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/582.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/598.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/100.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/74.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/617.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/644.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/68.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/581.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/83.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/588.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/107.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/609.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/146.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/571.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/161.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/140 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/698.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/681.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/528.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/618.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/594.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/624.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/578.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/120 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/585.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/139.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/676.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/675.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/696.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/638.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/122 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/602.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/161 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/86.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/523.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/15.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/692.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/557.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/119.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/23 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/570.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/606.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/12.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/566.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/706.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/141.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/616.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/135 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/92.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/122.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/686.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/11.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/592.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/652.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/596.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/533.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/579.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/715.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/568.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/550.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/674.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/91 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/520.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/51.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/673.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/546.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/52.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/4.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/90 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/149 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/583.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/688.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/556.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/711.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/540.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/125.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/95.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/553.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/610.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/615.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/694.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/536.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/657.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/608.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/100 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/96.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/600.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/163 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/584.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/64 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/95 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/655.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/522.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/712.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/625.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/63.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/621.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/162.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/643.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/514.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/87.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/670.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/612.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/562.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/547.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/93.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/707.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/689.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/14.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/549.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/519.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/697.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/517.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/526.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/607.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/637.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/119 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/614.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/63 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/648.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/108.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/679.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/714.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/542.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/66.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/632.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/647.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/544.png
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/593.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/551.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/134.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/635.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/0 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/597.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/136.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/605.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/90.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/599.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/White/147.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/81 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/56.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/58.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/76.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/501.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/399.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/429.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/377.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/143.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/385.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/497.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/115.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/74 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/402.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/50 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/507.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/425.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/5.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/55 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/426.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/8.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/84.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/486.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/67.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/78 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/82.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/443.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/437.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/436.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/30.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/442.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/113.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/38.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/34 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/447.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/33.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/10.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/54.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/478.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/480.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/380.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/35.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/512.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/379.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/375.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/80 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/408.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/494.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/481.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/80 (3).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/499.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/112.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/372.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/374.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/444.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/428.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/382.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/37.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/435.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/113 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/79 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/468.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/414.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/75.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/403.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/117.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/81.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/381.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/393.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/52 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/424.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/39 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/404.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/477.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/455.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/504.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/38 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/26 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/405.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/50.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/395.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/29.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/491.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/446.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/415.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/482.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/79.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/390.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/439.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/419.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/457.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/500.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/105.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/473.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/55.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/21 (2).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/145.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/7.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/77.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/80.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/433.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/461.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/430.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/458.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/116 (3).jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/487.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/427.jpeg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/28.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/22.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/378.jpg
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/509.webp
# /kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data/dark brown/472.jpeg
# ...
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (636).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (233).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (413).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (504).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (330).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (432).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (354).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (999).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (393).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (18).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (464).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (437).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (812).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (431).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (363).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (172).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (410).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (130).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (961).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (659).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (803).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (446).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (455).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (993).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (80).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (970).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (876).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (258).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (110).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (501).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (423).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (405).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (800).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (334).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (355).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (428).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (51).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (617).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (113).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (35).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (304).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (817).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (190).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (672).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (268).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (2).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (793).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (902).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (661).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (850).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (230).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (52).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (79).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (500).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (880).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (92).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (805).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (115).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (717).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (972).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (24).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (648).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (94).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (409).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (518).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (388).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (810).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (351).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (245).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (454).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (103).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (168).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (221).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (214).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (43).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (569).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (977).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (384).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (287).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (615).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (340).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (63).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (945).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (934).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (71).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (642).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (737).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (424).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (931).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (252).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (182).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (441).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (122).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (60).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (359).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (973).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (620).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (100).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (858).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (606).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (612).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (378).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (429).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (305).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (853).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (720).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (951).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (525).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (299).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (273).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (425).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (601).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (653).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (138).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (946).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (753).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (565).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (178).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (490).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (41).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (371).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (989).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (342).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (414).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (536).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (265).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (942).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (787).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (373).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (665).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (859).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (263).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (248).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (795).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (399).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (187).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (510).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (582).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (176).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (527).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (358).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (592).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (635).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (844).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (755).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (614).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (72).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (519).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (937).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (169).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (285).jpg
# /kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set/Oblong/oblong (836).jpg

# %% [markdown]
# # CNN-Based Skin Tone and Face Shape Classification
#
# ## Dataset Exploration and Visualization
#
# In this notebook, we perform exploratory data analysis (EDA) on two computer vision datasets before training Convolutional Neural Networks (CNNs).
#
# ### Objectives
#
# - Load and inspect the Skin Tone dataset.
# - Load and inspect the Face Shape dataset.
# - Apply image preprocessing and transformations.
# - Create PyTorch DataLoaders for efficient batching.
# - Visualize sample images from each dataset.
# - Analyze class distributions.
# - Verify dataset integrity before model training.
#
# ### Datasets
#
# #### 1. Skin Tone Dataset
# - Classes: Olive, White, Dark Brown
# - Total Images: 926
# - Purpose: Skin tone classification
#
# #### 2. Face Shape Dataset
# - Classes: Heart, Oblong, Oval, Round, Square
# - Total Images: 4000
# - Purpose: Face shape classification
#
# ### Why Perform Dataset Visualization?
#
# Visualizing the datasets helps us:
#
# - Understand the available classes.
# - Detect class imbalance.
# - Verify image quality.
# - Ensure preprocessing is working correctly.
# - Build confidence before training the CNN models.
#
# The following sections explore both datasets through image samples and class distribution visualizations.

# %% [markdown]
# # pytorch skin tone and face dataset loading implementation

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import numpy as np 
import pandas as pd
# ==========================================
# TRANSFORMS
# ==========================================

data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# ==========================================
# DATASET 1 : SKIN TONE
# ==========================================

skin_dataset = datasets.ImageFolder(
    root="/kaggle/input/datasets/omarelsherif010/skin-tone-classification/skin tone classification data",
    transform=data_transforms
)

skin_loader = DataLoader(
    skin_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=2
)



# ==========================================
# CHECK SKIN DATASET
# ==========================================

print("=" * 50)
print("SKIN DATASET")
print("=" * 50)

print("Classes:", skin_dataset.classes)
print("Class Mapping:", skin_dataset.class_to_idx)
print("Total Images:", len(skin_dataset))

images, labels = next(iter(skin_loader))

print("Image Shape:", images.shape)
print("Label Shape:", labels.shape)
print("Sample Labels:", labels)
# Out:
# ==================================================
# SKIN DATASET
# ==================================================
# Classes: ['Olive', 'White', 'dark brown']
# Class Mapping: {'Olive': 0, 'White': 1, 'dark brown': 2}
# Total Images: 926
# Image Shape: torch.Size([32, 3, 224, 224])
# Label Shape: torch.Size([32])
# Sample Labels: tensor([2, 1, 1, 2, 0, 0, 0, 1, 2, 0, 2, 0, 2, 1, 1, 2, 1, 1, 2, 2, 2, 2, 1, 0,
#         2, 0, 1, 2, 1, 1, 1, 1])

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
import os

train_dir = "/kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set"

print(os.listdir(train_dir))
# Out:
# ['Oval', 'Heart', 'Round', 'Square', 'desktop.ini', 'Oblong']

# %%
# ==========================================
# DATASET 2 : FACE SHAPE (Only if it has class folders)
# ==========================================

face_dataset = datasets.ImageFolder(
    root="/kaggle/input/datasets/niten19/face-shape-dataset/FaceShape Dataset/training_set",
    transform=data_transforms
)

face_loader = DataLoader(
    face_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=2
)

# ==========================================
# CHECK FACE DATASET
# ==========================================

print("\n" + "=" * 50)
print("FACE DATASET")
print("=" * 50)

print("Classes:", face_dataset.classes)
print("Class Mapping:", face_dataset.class_to_idx)
print("Total Images:", len(face_dataset))

images, labels = next(iter(face_loader))

print("Image Shape:", images.shape)
print("Label Shape:", labels.shape)
print("Sample Labels:", labels)
# Out:
# ==================================================
# FACE DATASET
# ==================================================
# Classes: ['Heart', 'Oblong', 'Oval', 'Round', 'Square']
# Class Mapping: {'Heart': 0, 'Oblong': 1, 'Oval': 2, 'Round': 3, 'Square': 4}
# Total Images: 4000
# Image Shape: torch.Size([32, 3, 224, 224])
# Label Shape: torch.Size([32])
# Sample Labels: tensor([0, 0, 3, 0, 0, 0, 3, 1, 3, 0, 1, 1, 3, 1, 1, 1, 3, 1, 4, 1, 0, 1, 4, 1,
#         2, 1, 1, 0, 4, 3, 1, 3])

# %% [markdown]
# # visuliazation of images

# %%
import matplotlib.pyplot as plt

images, labels = next(iter(skin_loader))

image = images[0]
label = labels[0]

plt.imshow(image.permute(1, 2, 0))
plt.title(f"Class: {skin_dataset.classes[label]}")
plt.axis("off")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].

# %%
fig, axes = plt.subplots(3, 3, figsize=(8,8))

images, labels = next(iter(skin_loader))

for i, ax in enumerate(axes.flat):
    ax.imshow(images[i].permute(1,2,0))
    ax.set_title(skin_dataset.classes[labels[i]])
    ax.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0494049..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.465708].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9656862..2.622571].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9306722..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0357141..2.3585434].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0357141..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..1.9920369].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.0947855].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].

# %% [markdown]
# # Number of images in each class

# %%
from collections import Counter

counts = Counter(skin_dataset.targets)

labels = skin_dataset.classes
values = [counts[i] for i in range(len(labels))]

plt.figure(figsize=(6,4))
plt.bar(labels, values)
plt.title("Skin Tone Distribution")
plt.xlabel("Class")
plt.ylabel("Images")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(
    values,
    labels=labels,
    autopct="%1.1f%%"
)
plt.title("Skin Tone Classes")
plt.show()

# %% [markdown]
# # Face Shape Distribution

# %%
counts = Counter(face_dataset.targets)

labels = face_dataset.classes
values = [counts[i] for i in range(len(labels))]

plt.figure(figsize=(7,4))
plt.bar(labels, values)
plt.title("Face Shape Distribution")
plt.xlabel("Face Shape")
plt.ylabel("Images")
plt.show()

# %% [markdown]
# # Mean image size

# %%
print("Batch Shape:", images.shape)

print("Channels:", images.shape[1])
print("Height:", images.shape[2])
print("Width:", images.shape[3])
# Out:
# Batch Shape: torch.Size([32, 3, 224, 224])
# Channels: 3
# Height: 224
# Width: 224

# %% [markdown]
# # CNN Model Architecture
#
# ## Building the Convolutional Neural Network
#
# After exploring and preprocessing the datasets, the next step is to build a Convolutional Neural Network (CNN).
#
# A CNN automatically learns important visual features from images, such as edges, textures, shapes, and patterns. These learned features are then used to classify each image into its corresponding category.
#
# The model is implemented using PyTorch's `nn.Sequential`, which allows multiple layers to be stacked in the order they are executed.
#
# ### CNN Architecture Overview
#
# The network consists of:
#
# - Convolutional layers for feature extraction.
# - ReLU activation functions to introduce non-linearity.
# - Max Pooling layers to reduce spatial dimensions.
# - Fully Connected (Linear) layers for classification.
# - A final output layer matching the number of classes.
#
# ### Workflow
#
# Input Image (224 × 224 × 3)
#
# ↓
#
# Convolution + ReLU
#
# ↓
#
# Max Pooling
#
# ↓
#
# Convolution + ReLU
#
# ↓
#
# Max Pooling
#
# ↓
#
# Flatten
#
# ↓
#
# Fully Connected Layer
#
# ↓
#
# Output Layer (Class Prediction)
#
# The same CNN architecture will be trained separately for the Skin Tone dataset and the Face Shape dataset.

# %%
class CNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.model = torch.nn.Sequential(

            # Block 1
            torch.nn.Conv2d(3, 32, kernel_size=3, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),

            # Block 2
            torch.nn.Conv2d(32, 64, kernel_size=3, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),

            # Block 3
            torch.nn.Conv2d(64, 64, kernel_size=3, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),

            torch.nn.Flatten(),

            torch.nn.Linear(64 * 28 * 28, 512),
            torch.nn.ReLU(),

            torch.nn.Linear(512, num_classes)
        )

    def forward(self, x):
        return self.model(x)
skin_model = CNN(num_classes=3)
face_model = CNN(num_classes=5)
print(skin_model)
print(face_model)
# Out:
# CNN(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=50176, out_features=512, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=512, out_features=3, bias=True)
#   )
# )
# CNN(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=50176, out_features=512, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=512, out_features=5, bias=True)
#   )
# )

# %% [markdown]
# # loss functions and optimizers

# %% [markdown]
# # Model Training
#
# ## Training the CNN
#
# Once the CNN architecture has been defined, the model is trained using the prepared datasets.
#
# During training, the network compares its predictions with the true labels using a loss function. The optimizer then updates the model's parameters through backpropagation, allowing the CNN to gradually improve its predictions over multiple epochs.
#
# ### Training Components
#
# - Loss Function: CrossEntropyLoss
# - Optimizer: Adam
# - Batch Size: 32
# - Image Size: 224 × 224
# - Epochs: Defined during training
#
# ### Training Process
#
# For each epoch:
#
# 1. Load a batch of images.
# 2. Perform a forward pass through the CNN.
# 3. Compute the classification loss.
# 4. Calculate gradients using backpropagation.
# 5. Update the model parameters.
# 6. Repeat until all batches have been processed.
#
# The training loss is monitored after every epoch to evaluate how effectively the model is learning from the data.

# %%
import torch

def train_model(model, train_loader, criterion, optimizer, epochs, device):

    model.to(device)

    train_losses = []
    train_accuracies = []

    for epoch in range(epochs):

        model.train()

        running_loss = 0.0
        correct = 0
        total = 0

        for images, labels in train_loader:

            images = images.to(device)
            labels = labels.to(device)

            # Forward Pass
            outputs = model(images)

            # Loss
            loss = criterion(outputs, labels)

            # Clear Previous Gradients
            optimizer.zero_grad()

            # Backpropagation
            loss.backward()

            # Update Weights
            optimizer.step()

            # Statistics
            running_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = 100 * correct / total

        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)

        print(
            f"Epoch [{epoch+1}/{epochs}] | "
            f"Loss: {epoch_loss:.4f} | "
            f"Accuracy: {epoch_accuracy:.2f}%"
        )

    return train_losses, train_accuracies

# %%
criterion = torch.nn.CrossEntropyLoss()

skin_optimizer = torch.optim.Adam(
    skin_model.parameters(),
    lr=0.001
)

face_optimizer = torch.optim.Adam(
    face_model.parameters(),
    lr=0.001
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Train Skin Tone Model

# %%
skin_losses, skin_acc = train_model(
    model=skin_model,
    train_loader=skin_loader,
    criterion=criterion,
    optimizer=skin_optimizer,
    epochs=10,
    device=device
)
# Out:
# Epoch [1/10] | Loss: 1.2032 | Accuracy: 52.27%
# Epoch [2/10] | Loss: 0.5821 | Accuracy: 74.84%
# Epoch [3/10] | Loss: 0.5152 | Accuracy: 78.94%
# Epoch [4/10] | Loss: 0.3727 | Accuracy: 84.56%
# Epoch [5/10] | Loss: 0.2288 | Accuracy: 91.58%
# Epoch [6/10] | Loss: 0.1049 | Accuracy: 96.76%
# Epoch [7/10] | Loss: 0.0985 | Accuracy: 96.65%
# Epoch [8/10] | Loss: 0.0956 | Accuracy: 97.41%
# Epoch [9/10] | Loss: 0.0797 | Accuracy: 97.52%
# Epoch [10/10] | Loss: 0.0832 | Accuracy: 97.62%

# %% [markdown]
# # Train Face Shape Model

# %%
face_losses, face_acc = train_model(
    model=face_model,
    train_loader=face_loader,
    criterion=criterion,
    optimizer=face_optimizer,
    epochs=10,
    device=device
)
# Out:
# Epoch [1/10] | Loss: 1.6820 | Accuracy: 19.57%
# Epoch [2/10] | Loss: 1.6097 | Accuracy: 20.00%
# Epoch [3/10] | Loss: 1.6097 | Accuracy: 20.00%
# Epoch [4/10] | Loss: 1.6097 | Accuracy: 18.48%
# Epoch [5/10] | Loss: 1.6096 | Accuracy: 19.73%
# Epoch [6/10] | Loss: 1.6096 | Accuracy: 19.68%
# Epoch [7/10] | Loss: 1.6096 | Accuracy: 19.05%
# Epoch [8/10] | Loss: 1.6096 | Accuracy: 19.05%
# Epoch [9/10] | Loss: 1.6096 | Accuracy: 18.93%
# Epoch [10/10] | Loss: 1.6096 | Accuracy: 18.70%

# %% [markdown]
# # Training Performance Visualization
#
# ## Loss and Accuracy Curves
#
# After training the CNN for multiple epochs, we visualize the model's performance over time.
#
# The training loss indicates how well the model fits the training data, while the training accuracy measures the percentage of correctly classified images.
#
# These graphs help us determine whether the model is learning effectively and whether additional epochs are needed.
#
# ### Visualized Metrics
#
# - Training Loss
# - Training Accuracy
#
# An ideal training process shows a decreasing loss curve and an increasing accuracy curve, indicating that the CNN is successfully learning meaningful features from the images.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(skin_losses, marker='o')
plt.title("Skin Tone Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot Training Accuracy

# %%
plt.figure(figsize=(8,5))
plt.plot(skin_acc, marker='o')
plt.title("Skin Tone Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(face_losses, marker='o')
plt.title("Face Shape Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(face_acc, marker='o')
plt.title("Face Shape Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.grid(True)
plt.show()

# %%
torch.save(skin_model.state_dict(), "skin_tone_model.pth")
torch.save(face_model.state_dict(), "face_shape_model.pth")

print("Models saved successfully!")
# Out:
# Models saved successfully!

# %% [markdown]
# # Saving the Trained Models
#
# ## Model Persistence
#
# After successful training, the learned model parameters are saved to disk.
#
# Saving the trained models allows them to be reused later without repeating the training process. The saved models can be loaded during inference to classify new images efficiently.
#
# Two separate models are saved:
#
# - Skin Tone Classification Model
# - Face Shape Classification Model
#
# These models will be used in the recommendation system to predict facial characteristics from uploaded images.
